# %% [markdown]
# # DC Data Repro Notebook

# %% [markdown]
# Set up a Header and then set up markdown and write text in it. Yay.

# %%
3**2
# Out:
# 9

# %%
3 + 4
# Out:
# 7

# %%
6* 7
# Out:
# 42

# %%
18 - 7
# Out:
# 11

# %%
#doing some math and it is fun
5 - 3
# Out:
# 2

# %%
 a = 5

# %%
a
# Out:
# 5

# %%
b = 4

# %%
a + b
# Out:
# 9

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2*np.pi*t)
plt.plot(t, s)

plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.grid(True)
plt.savefig("test.png")
plt.show()

# %%
import pylab
import numpy

x = numpy.linspace(-15,15,100) # 100 linearly spaced numbers
y = numpy.sin(x)/x # computing the values of sin(x)/x

# compose plot
pylab.plot(x,y) # sin(x)/x
pylab.plot(x,y,'co') # same function with cyan dots
pylab.plot(x,2*y,x,3*y) # 2*sin(x)/x and 3*sin(x)/x
pylab.show() # show the plot
